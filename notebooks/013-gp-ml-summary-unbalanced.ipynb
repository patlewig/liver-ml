# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pylab as pl
import scipy as sp
import sys
import openpyxl
import os, sys

# %matplotlib inline

# %%
from box import Box
import glob

# %%
TOP = os.getcwd().replace("notebooks/tt", "")
D1 = TOP + 'data/'
figures_dir = TOP + 'manuscript/figures/'

# %%
df = pd.read_excel(D1+'unbalanced_all_190123.xlsx', sheet_name = 'all', index_col = [0])

# %%
df[df['tox'] == 'chr_liver'].describe()
# Out:
#          mean_f1     std_f1  mean_sensitivity  std_sensitivity  \
# count  40.000000  40.000000         40.000000        40.000000
# mean    0.728475   0.042200          0.804050         0.077850
# std     0.084401   0.042175          0.164548         0.054683
# min     0.461000   0.003000          0.385000         0.000000
# 25%     0.731250   0.019750          0.756000         0.038750
# 50%     0.751000   0.031000          0.822000         0.071000
# 75%     0.780250   0.053000          0.898500         0.114500
# max     0.789000   0.173000          1.000000         0.200000
#
#        mean_specificity  std_specificity  mean_accuracy  std_accuracy  \
# count         40.000000        40.000000      40.000000     40.000000
# mean           0.316375         0.106650       0.632475      0.037275
# std            0.203755         0.062572       0.054648      0.023754
# min            0.000000         0.000000       0.442000      0.004000
# ...

# %%
df[(df['tox'] == 'dev_liver') & (df['mean_f1'] >0)].describe()
# Out:
#          mean_f1     std_f1  mean_sensitivity  std_sensitivity  \
# count  19.000000  19.000000         19.000000        19.000000
# mean    0.083105   0.111895          0.073000         0.089421
# std     0.050419   0.038375          0.094733         0.063330
# min     0.027000   0.060000          0.022000         0.050000
# 25%     0.040000   0.078500          0.022000         0.050000
# 50%     0.082000   0.092000          0.067000         0.061000
# 75%     0.110000   0.153000          0.069000         0.101000
# max     0.229000   0.165000          0.444000         0.324000
#
#        mean_specificity  std_specificity  mean_accuracy  std_accuracy  \
# count         19.000000        19.000000      19.000000     19.000000
# mean           0.925842         0.048211       0.785263      0.042789
# std            0.099136         0.044798       0.069261      0.032167
# min            0.558000         0.012000       0.540000      0.020000
# ...
